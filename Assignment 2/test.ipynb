# %%
import word2vec.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b7df3cfbfb1e> in <module>
# ----> 1 import word2vec.py
#
# ModuleNotFoundError: No module named 'word2vec.py'; 'word2vec' is not a package

# %% [markdown]
# xO= uTOvc​ ，tO=exp(xO)​，$so=\sum{w \in Vocab} exp(x_w)​，\hat{y_o} = g _o=\frac{t_o}{s_o}​, Under the surface ofX_o$ Derivation
#
# ∴ J=−log( andO^) = - l n ( gO)​ (The log here means ln)
#
# ∵ t′O=tO=exO​，s′=exO​
# ∵ g′O=t′OsO−tOs′Os2O=gO(1−gO)​
#
# ∴ ∂J∂xO=∂J∂gO⋅∂gO∂xO= yO^- andO
#
# Right vc​ The derivative is:
#
# ∂J∂vc=∂J∂xO⋅∂xO∂vc= ( andO^- andO)⋅uT​Introduce the matrix to:
#
# Jnative−softmax= ( vc, o , U) = ( and^- and)⋅U​

# %%
import word2vec

# %%
#!word2vec.py

# %%
# !python word2vec.py
# Out:
# ==== Gradient check for skip-gram with naiveSoftmaxLossAndGradient ====
# [0.41703564 0.10030664 0.12391154 0.10888915 0.24985703]
# [ 0.41703564  0.10030664  0.12391154 -0.89111085  0.24985703]
# [0.41703564 0.10030664 0.12391154 0.10888915 0.24985703]
# [-0.58296436  0.10030664  0.12391154  0.10888915  0.24985703]
# [0.41703564 0.10030664 0.12391154 0.10888915 0.24985703]
# [ 0.41703564  0.10030664  0.12391154  0.10888915 -0.75014297]
# [0.41703564 0.10030664 0.12391154 0.10888915 0.24985703]
# [ 0.41703564  0.10030664  0.12391154  0.10888915 -0.75014297]
# [0.41703564 0.10030664 0.12391154 0.10888915 0.24985703]
# [ 0.41703564  0.10030664  0.12391154 -0.89111085  0.24985703]
# [0.41703564 0.10030664 0.12391154 0.10888915 0.24985703]
# [ 0.41703564 -0.89969336  0.12391154  0.10888915  0.24985703]
# [0.41703564 0.10030664 0.12391154 0.10888915 0.24985703]
# [ 0.41703564  0.10030664 -0.87608846  0.10888915  0.24985703]
# [0.41703564 0.10030664 0.12391154 0.10888915 0.24985703]
# ...

# %%
import sgd

# %%
# !python sgd.py
# Out:
# Running sanity checks...
# iter 100: 0.004578
# iter 200: 0.004353
# iter 300: 0.004136
# iter 400: 0.003929
# iter 500: 0.003733
# iter 600: 0.003546
# iter 700: 0.003369
# iter 800: 0.003200
# iter 900: 0.003040
# iter 1000: 0.002888
# test 1 result: 8.414836786079764e-10
# iter 100: 0.000000
# iter 200: 0.000000
# iter 300: 0.000000
# iter 400: 0.000000
# iter 500: 0.000000
# iter 600: 0.000000
# iter 700: 0.000000
# iter 800: 0.000000
# iter 900: 0.000000
# iter 1000: 0.000000
# test 2 result: 0.0
# iter 100: 0.041205
# iter 200: 0.039181
# iter 300: 0.037222
# iter 400: 0.035361
# iter 500: 0.033593
# iter 600: 0.031913
# iter 700: 0.030318
# iter 800: 0.028802
# iter 900: 0.027362
# iter 1000: 0.025994
# test 3 result: -2.524451035823933e-09
# ----------------------------------------
# ALL TESTS PASSED
# ----------------------------------------

# %%
import run
# Out:
# iter 10: 0.000000
# iter 20: 0.000000
# iter 30: 0.000000
# iter 40: 0.000000
# iter 50: 0.000000
# iter 60: 0.000000
# iter 70: 0.000000
# iter 80: 0.000000
# iter 90: 0.000000
# iter 100: 0.000000
# iter 110: 0.000000
# iter 120: 0.000000
# iter 130: 0.000000
# iter 140: 0.000000
# iter 150: 0.000000
# iter 160: 0.000000
# iter 170: 0.000000
# iter 180: 0.000000
# iter 190: 0.000000
# iter 200: 0.000000
# iter 210: 0.000000
# iter 220: 0.000000
# iter 230: 0.000000
# iter 240: 0.000000
# iter 250: 0.000000
# iter 260: 0.000000
# iter 270: 0.000000
# iter 280: 0.000000
# iter 290: 0.000000
# iter 300: 0.000000
# iter 310: 0.000000
# iter 320: 0.000000
# iter 330: 0.000000
# iter 340: 0.000000
# iter 350: 0.000000
# iter 360: 0.000000
# iter 370: 0.000000
# iter 380: 0.000000
# iter 390: 0.000000
# iter 400: 0.000000
# iter 410: 0.000000
# iter 420: 0.000000
# iter 430: 0.000000
# iter 440: 0.000000
# iter 450: 0.000000
# iter 460: 0.000000
# iter 470: 0.000000
# iter 480: 0.000000
# ...

# %%
# !python run.py
